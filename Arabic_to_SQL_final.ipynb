# %%
import json
import re
import unicodedata
import pandas as pd
from pathlib import Path

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Arabic to SQL Data/Text To SQL Task-20250223T185920Z-001.zip" -d "/content/dataset"
# Out:
# Archive:  /content/drive/MyDrive/Arabic to SQL Data/Text To SQL Task-20250223T185920Z-001.zip
#   inflating: /content/dataset/Text To SQL Task/Text to SQL.docx
#   inflating: /content/dataset/Text To SQL Task/Papers/Survey of LLM-based Text-to-SQL.pdf
#   inflating: /content/dataset/Text To SQL Task/Papers/Text-to-SQL in Arabic.pdf
#   inflating: /content/dataset/Text To SQL Task/Papers/deep learning survey.pdf
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/coffee_shop/coffee_shop.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/company_employee/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/apartment_rentals/apartment_rentals.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cinema/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/college_1/TinyCollege.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/academic/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Papers/Structure Guided Large Language Model for SQL Generation.pdf
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/college_1/college_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/apartment_rentals/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Doc_Control_Systems/cre_Doc_Control_Systems.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Doc_Template_Mgt/cre_Doc_Template_Mgt.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cinema/cinema.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/AR_spider.jsonl
#   inflating: /content/dataset/Text To SQL Task/Papers/ttsql.pdf
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/battle_death/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/academic/academic.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Doc_Control_Systems/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/company_1/company_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/allergy_1/allergy_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/company_1/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/bike_1/bike_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/college_1/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/coffee_shop/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/allergy_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/book_2/book_2.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/body_builder/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/climbing/climbing.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/body_builder/body_builder.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/q.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/battle_death/battle_death.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/college_3/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/company_employee/company_employee.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/behavior_monitoring/behavior_monitoring.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/architecture/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/car_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/climbing/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/college_3/college_3.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Doc_Template_Mgt/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/car_1.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/book_2/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/annotation.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/car_1.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/candidate_poll/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/behavior_monitoring/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/browser_web/browser_web.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/architecture/architecture.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/city_record/city_record.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/browser_web/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/county_public_safety/county_public_safety.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/company_office/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/activity_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/club_1/club_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/concert_singer/concert_singer.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/bike_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/aircraft/aircraft.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/company_office/company_office.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/city_record/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/chinook_1/chinook_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/aircraft/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/college_2/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_and_invoices/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/club_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/concert_singer/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/candidate_poll/candidate_poll.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/assets_maintenance/assets_maintenance.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/activity_1/activity_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/chinook_1/annotation.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customer_complaints/customer_complaints.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Theme_park/cre_Theme_park.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customer_complaints/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/assets_maintenance/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/county_public_safety/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Theme_park/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/decoration_competition/decoration_competition.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Drama_Workshop_Groups/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/course_teach/course_teach.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customer_deliveries/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Docs_and_Epenses/cre_Docs_and_Epenses.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_and_products_contacts/customers_and_products_contacts.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Drama_Workshop_Groups/cre_Drama_Workshop_Groups.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/decoration_competition/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Doc_Tracking_DB/cre_Doc_Tracking_DB.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customer_deliveries/customer_deliveries.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_and_products_contacts/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_card_transactions/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/document_management/document_management.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Docs_and_Epenses/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_card_transactions/customers_card_transactions.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/document_management/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/debate/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/culture_company/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/election_representative/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/election_representative/election_representative.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/culture_company/culture_company.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/csu_1/csu_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/course_teach/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/college_2/TextBookExampleSchema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/debate/debate.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_and_invoices/customers_and_invoices.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/dorm_1/dorm_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/dorm_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/cre_Doc_Tracking_DB/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/csu_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/driving_school/driving_school.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/department_management/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/entertainment_awards/entertainment_awards.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_and_addresses/customers_and_addresses.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/device/device.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/e_government/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/department_management/department_management.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/dog_kennels/dog_kennels.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/entertainment_awards/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/election/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/driving_school/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_campaigns_ecommerce/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/farm/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/college_2/college_2.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/employee_hire_evaluation/employee_hire_evaluation.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/device/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/e_learning/e_learning.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/farm/farm.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_1/flight_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_campaigns_ecommerce/customers_campaigns_ecommerce.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/entrepreneur/entrepreneur.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/game_injury/game_injury.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/department_store/department_store.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/formula_1.splite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_4/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/epinions_1/epinions_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/department_store/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/employee_hire_evaluation/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/geo/geo.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/customers_and_addresses/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/e_learning/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/entrepreneur/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/election/election.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_4/sql.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/flight_2.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/dog_kennels/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/e_government/e_government.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/flight_2.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/annotation.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/game_injury/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/hospital_1/hospital_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/hospital_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/q.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/flight_2.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/game_1/game_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/formula_1.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/icfp_1/icfp_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/gas_company/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/annotation.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/insurance_and_eClaims/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/geo/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/game_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/imdb/imdb.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/gymnast/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/gymnast/gymnast.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/hr_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/insurance_and_eClaims/insurance_and_eClaims.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/mountain_photos/mountain_photos.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_4/flight_4.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/formula_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/icfp_1/q.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/imdb/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/hr_1/hr_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/gas_company/gas_company.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/manufactory_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/local_govt_mdm/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/insurance_fnol/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/manufactory_1/manufactory_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/local_govt_mdm/local_govt_mdm.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/insurance_fnol/insurance_fnol.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/local_govt_in_alabama/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/q.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/machine_repair/machine_repair.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/change_date.py
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/machine_repair/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/journal_committee/journal_committee.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/film_rank/film_rank.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/annotation.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/film_rank/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/music_1/music_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/inn_1.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_company/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/inn_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/local_govt_in_alabama/local_govt_in_alabama.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/match_season/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/mountain_photos/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/journal_committee/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/loan_1/loan_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/baseball_1/baseball_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/local_govt_and_lot/local_govt_and_lot.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/orchestra/orchestra.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/medicine_enzyme_interaction/medicine_enzyme_interaction.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/manufacturer/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_company/flight_company.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/local_govt_and_lot/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/manufacturer/manufacturer.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/orchestra/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/network_2/network_2.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/pilot_record/pilot_record.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/music_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/medicine_enzyme_interaction/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/movie_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/museum_visit/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/movie_1/movie_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/phone_1/phone_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/match_season/match_season.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/party_host/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/insurance_policies/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/insurance_policies/insurance_policies.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/phone_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/icfp_1/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/pilot_record/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/baseball_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/music_2/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/poker_player/poker_player.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/program_share/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/network_2/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/program_share/program_share.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/perpetrator/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/musical/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/restaurant_1/restaurant_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/party_host/party_host.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/musical/musical.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/network_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/network_1/network_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/performance_attendance/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/museum_visit/museum_visit.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/restaurant_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/performance_attendance/performance_attendance.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/music_4/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/music_4/music_4.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/protein_institute/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/loan_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/product_catalog/product_catalog.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/music_2/music_2.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/phone_market/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/protein_institute/protein_institute.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/products_gen_characteristics/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/products_gen_characteristics/products_gen_characteristics.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/product_catalog/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/pets_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/phone_market/phone_market.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/poker_player/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/perpetrator/perpetrator.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/real_estate_properties/real_estate_properties.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/restaurants/restaurants.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/news_report/news_report.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/railway/railway.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/race_track/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/pets_1/pets_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/restaurants/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/products_for_hire/products_for_hire.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/railway/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/party_people/party_people.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/riding_club/riding_club.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/party_people/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/roller_coaster/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/roller_coaster/roller_coaster.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/ship_mission/ship_mission.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/school_finance/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/school_bus/school_bus.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/school_bus/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/products_for_hire/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/race_track/race_track.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/ship_mission/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/scholar/scholar.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/school_player/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/news_report/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/real_estate_properties/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/soccer_2/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/school_finance/school_finance.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/store_product/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/scholar/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/riding_club/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/shop_membership/shop_membership.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/store_product/store_product.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/sakila_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/school_player/school_player.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_1/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/shop_membership/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/ship_1/ship_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/singer/singer.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/sakila_1/sakila_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/singer/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/ship_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/scientist_1/scientist_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tracking_share_transactions/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tracking_share_transactions/tracking_share_transactions.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/soccer_2/soccer_2.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_1/q.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/station_weather/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_transcripts_tracking/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/store_1/store_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/scientist_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/station_weather/station_weather.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/swimming/swimming.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_1/student_1.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/store_1/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tvshow/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/small_bank_1/small_bank_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/swimming/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_1/annotation.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_assessment/student_assessment.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/storm_record/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tracking_grants_for_research/tracking_grants_for_research.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/theme_gallery/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/storm_record/storm_record.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tracking_software_problems/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/sports_competition/sports_competition.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/sports_competition/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/solvency_ii/solvency_ii.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_transcripts_tracking/student_transcripts_tracking.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tracking_software_problems/tracking_software_problems.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/world_1/world_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tracking_orders/tracking_orders.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/voter_2/voter_2.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tvshow/tvshow.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_assessment/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_1/student_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tracking_orders/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wedding/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/train_station/train_station.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/twitter_1/twitter_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/data_csv/airlines.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wedding/wedding.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/data_csv/flights.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/voter_2/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/theme_gallery/theme_gallery.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/yelp/yelp.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/link.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wrestler/wrestler.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/tracking_grants_for_research/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/university_basketball/university_basketball.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/data_csv/airports100.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/solvency_ii/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/train_station/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/university_basketball/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wrestler/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/data_csv/Rooms.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/wine_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/wine_1.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/yelp/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_1/data_csv/README.STUDENTS.TXT
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/annotation.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/workshop_paper/workshop_paper.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wta_1/wta_1.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/world_1/world_1.json
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/data_csv/README.INN.TXT
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/workshop_paper/schema.sql
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_1/data_csv/teachers.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/voter_1/voter_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/data_csv/Reservations_t.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/data_csv/grapes.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/constructors.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/constructorResults.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/q.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/seasons.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/flight_2/data_csv/README.AIRLINES.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/drivers.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/student_1/data_csv/list.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/constructorStandings.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/inn_1/data_csv/Reservations.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/twitter_1/queries/postgres-dialects.xml
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/data_csv/continents.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/status.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/data_csv/cars.desc
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/data_csv/appellations.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/results.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/data_csv/README.WINE.txt
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/data_csv/car-names.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wine_1/data_csv/wine.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/data_csv/car-makers.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/circuits.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/data_csv/countries.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/pitStops.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/data_csv/cars-data.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/twitter_1/queries/oracle-dialects.xml
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/qualifying.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/data_csv/README.CARS.TXT
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/races.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/twitter_1/queries/sqlserver-dialects.xml
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/car_1/data_csv/model-list.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/driverStandings.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/formula_1/data_csv/lapTimes.csv
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/wta_1/wta_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/soccer_1/soccer_1.sqlite
#   inflating: /content/dataset/Text To SQL Task/Dataset/database/soccer_1/schema.sql

# %%
jsonl_path = "/content/dataset/Text To SQL Task/Dataset/AR_spider.jsonl"
data = []

# %%
with open(jsonl_path, "r", encoding="utf-8") as file:
    for line in file:
        entry = json.loads(line.strip())
        data.append({
            "arabic": entry["arabic"],
            "sql": entry["query"],
            "db_id": entry["db_id"]
        })

# %%
def normalize_arabic(text):
    """Normalize Arabic text by removing diacritics and normalizing characters."""
    text = unicodedata.normalize("NFKC", text)  # Unicode normalization
    text = re.sub(r"[\u064B-\u065F]", "", text)  # Remove diacritics
    text = text.replace("ى", "ي").replace("ة", "ه")  # Normalize letters
    return text.strip()

# %%
def tokenize_sql(query):
    """Ensure SQL queries are tokenized properly by spacing special characters."""
    query = re.sub(r"([,()=<>])", r" \1 ", query)
    query = re.sub(r"\s+", " ", query)
    return query.strip()

# %%
processed_data = []
for entry in data:
    processed_data.append({
        "arabic": normalize_arabic(entry["arabic"]),
        "sql": tokenize_sql(entry["sql"]),
        "db_id": entry["db_id"]
    })

# %%
output_df = pd.DataFrame(processed_data)
output_df.to_csv("processed_arabic_sql.csv", index=False, encoding="utf-8")

print("Preprocessing complete. Data saved to processed_arabic_sql.csv.")
# Out:
# Preprocessing complete. Data saved to processed_arabic_sql.csv.

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.14)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.29.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.4.1-py3-none-any.whl (487 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 13.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.8 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 15.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed datasets-3.4.1 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
import torch
import pandas as pd
from datasets import load_dataset, Dataset
from transformers import MBartForConditionalGeneration, MBartTokenizer, Trainer, TrainingArguments
from transformers import MBart50Tokenizer

# %%
df = pd.read_csv("/content/processed_arabic_sql.csv")

# %%
def preprocess_function(examples, tokenizer):
    """Tokenize Arabic text (input) and SQL query (target)."""
    model_inputs = tokenizer(examples["arabic"], padding="max_length", truncation=True, max_length=128)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["sql"], padding="max_length", truncation=True, max_length=128)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
raw_datasets = Dataset.from_pandas(df)
model_name = "facebook/mbart-large-50"
tokenizer = MBart50Tokenizer.from_pretrained(model_name, src_lang="ar_AR", tgt_lang="en_XX")
tokenized_datasets = raw_datasets.map(lambda x: preprocess_function(x, tokenizer), batched=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/531 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Map:   0%|          | 0/6396 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3970: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(

# %%
model = MBartForConditionalGeneration.from_pretrained(model_name)
# Out:
# pytorch_model.bin:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]

# %%
training_args = TrainingArguments(
    output_dir="./mbart_arabic_sql",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    learning_rate=5e-5,
    weight_decay=0.01,
    save_total_limit=2,
    logging_dir="./logs",
    logging_steps=500,
    report_to="none"
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1594: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets,
    eval_dataset=tokenized_datasets,
    tokenizer=tokenizer
)

trainer.train()
# Out:
# <ipython-input-17-6abd1c8e097b>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='2400' max='2400' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2400/2400 1:18:59, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.641300</td>
#       <td>0.131037</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.113800</td>
#       <td>0.059727</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.072100</td>
#       <td>0.035677</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:2810: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 200, 'early_stopping': True, 'num_beams': 5}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# TrainOutput(global_step=2400, training_loss=0.42770745992660525, metrics={'train_runtime': 4742.8227, 'train_samples_per_second': 4.046, 'train_steps_per_second': 0.506, 'total_flos': 5197860748394496.0, 'train_loss': 0.42770745992660525, 'epoch': 3.0})

# %%
trainer.save_model("./mbart_arabic_sql_finetuned")
tokenizer.save_pretrained("./mbart_arabic_sql_finetuned")
# Out:
# ('./mbart_arabic_sql_finetuned/tokenizer_config.json',
#  './mbart_arabic_sql_finetuned/special_tokens_map.json',
#  './mbart_arabic_sql_finetuned/sentencepiece.bpe.model',
#  './mbart_arabic_sql_finetuned/added_tokens.json')

# %%
import shutil

shutil.make_archive('/content/mbart_arabic_sql_finetuned', 'zip', '/content/mbart_arabic_sql_finetuned')
# Out:
# '/content/mbart_arabic_sql_finetuned.zip'

# %%
# !cp -r mbart_arabic_sql_finetuned /content/drive/MyDrive/

# %% [markdown]
# #Testing

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# %%
model_path = "/content/drive/MyDrive/mbart_arabic_sql_finetuned"

tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# MBartForConditionalGeneration(
#   (model): MBartModel(
#     (shared): MBartScaledWordEmbedding(250054, 1024, padding_idx=1)
#     (encoder): MBartEncoder(
#       (embed_tokens): MBartScaledWordEmbedding(250054, 1024, padding_idx=1)
#       (embed_positions): MBartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0-11): 12 x MBartEncoderLayer(
#           (self_attn): MBartSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): MBartDecoder(
#       (embed_tokens): MBartScaledWordEmbedding(250054, 1024, padding_idx=1)
#       (embed_positions): MBartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0-11): 12 x MBartDecoderLayer(
#           (self_attn): MBartSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): MBartSdpaAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=250054, bias=False)
# )

# %%
def arabic_to_sql(question):
    inputs = tokenizer(question, return_tensors="pt", padding=True, truncation=True).to(device)
    with torch.no_grad():
        outputs = model.generate(**inputs, max_length=256)
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
question_ar = "ما هي أسماء الطلاب الذين حصلوا على درجات أعلى من 90؟"
sql = arabic_to_sql(question_ar)
print("Arabic Question:", question_ar)
print("Generated SQL:", sql)
# Out:
# Arabic Question: ما هي أسماء الطلاب الذين حصلوا على درجات أعلى من 90؟
# Generated SQL: SELECT T1.stu_fname FROM student AS T1 JOIN enroll AS T2 ON T1.stu_num = T2.stu_num WHERE enroll_grade = 'C'

# %%
question_ar = "كم عدد رؤساء الأقسام الذين تزيد أعمارهم عن 56 سنه؟"
sql = arabic_to_sql(question_ar)
print("Arabic Question:", question_ar)
print("Generated SQL:", sql)
# Out:
# Arabic Question: كم عدد رؤساء الأقسام الذين تزيد أعمارهم عن 56 سنه؟
# Generated SQL: SELECT count ( * ) FROM head WHERE age > 56

# %%
question_ar = "ما هو رقم تعريفي التقسيم للمستخدم الذي يحمل اسم آيرون مان"
sql = arabic_to_sql(question_ar)
print("Arabic Question:", question_ar)
print("Generated SQL:", sql)
# Out:
# Arabic Question: ما هو رقم تعريفي التقسيم للمستخدم الذي يحمل اسم آيرون مان
# Generated SQL: SELECT count ( * ) FROM user_profiles WHERE name = 'Alice'

# %%
question_ar = "ما هو اسم الإدخال لأغلي فهرس (بالدولار الأمريكي)؟"
sql = arabic_to_sql(question_ar)
print("Arabic Question:", question_ar)
print("Generated SQL:", sql)
# Out:
# Arabic Question: ما هو اسم الإدخال لأغلي فهرس (بالدولار الأمريكي)؟
# Generated SQL: SELECT catalog_entry_name FROM catalog_contents ORDER BY price_in_dollars DESC LIMIT 1

# %%
question_ar = "ما هي المدن المختلفه التي يعيش فيها الأشخاص؟"
sql = arabic_to_sql(question_ar)
print("Arabic Question:", question_ar)
print("Generated SQL:", sql)
# Out:
# Arabic Question: ما هي المدن المختلفه التي يعيش فيها الأشخاص؟
# Generated SQL: SELECT DISTINCT city FROM people

# %%
question_ar = "لكل مدينه، ماهو أعلي خط عرض بين محطاتها؟"
sql = arabic_to_sql(question_ar)
print("Arabic Question:", question_ar)
print("Generated SQL:", sql)
# Out:
# Arabic Question: لكل مدينه، ماهو أعلي خط عرض بين محطاتها؟
# Generated SQL: SELECT city , max ( lat ) FROM station GROUP BY city

# %%
question_ar = "كم عدد المحطات في ماونتن فيو"
sql = arabic_to_sql(question_ar)
print("Arabic Question:", question_ar)
print("Generated SQL:", sql)
# Out:
# Arabic Question: كم عدد المحطات في ماونتن فيو
# Generated SQL: SELECT count ( * ) FROM station WHERE city = "Mountain View"

# %%
question_ar = "ما هي أسماء الطلاب الذين حصلوا على درجات اقل من 90؟"
sql = arabic_to_sql(question_ar)
print("Arabic Question:", question_ar)
print("Generated SQL:", sql)
# Out:
# Arabic Question: ما هي أسماء الطلاب الذين حصلوا على درجات اقل من 90؟
# Generated SQL: SELECT T2.name FROM student AS T1 JOIN enroll AS T2 ON T1.stuid = T2.stuid JOIN CLASS AS T3 ON T1.class_code = T3.class_code WHERE T3.crs_code = 'ACCT-211'
